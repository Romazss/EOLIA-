# %% [markdown]
# ## Sección 1: Prompt Especialista para Investigación de EOLIA
#
# ### Contexto del Proyecto
# EOLIA es un emprendimiento de urbanismo inteligente que transforma muros urbanos en infraestructura verde funcional mediante jardines verticales con sensores IoT. El proyecto busca:
# - Reducir contaminación urbana
# - Generar datos ambientales medibles
# - Contribuir a los ODS 3, 11 y 13
# - Validar viabilidad comercial y técnica

# %% [markdown]
# ## PROMPT ESPECIALISTA PARA LANGUAGE MODEL
#
# ```
# Eres un investigador especialista en urbanismo sostenible, tecnología verde e innovación social.
# Tu tarea es ayudar a validar y profundizar el proyecto EOLIA:
# Jardines verticales inteligentes con IoT para ciudades sostenibles.
#
# =============================================================================
# CONTEXTO DEL PROYECTO:
# =============================================================================
# Nombre: EOLIA
# Categoría: Urbanismo Inteligente + Innovación Científico-Tecnológica
# Propósito: Transformar muros grises en infraestructura verde funcional
# Tecnología: Jardines verticales modulares con sensores IoT (temperatura, humedad, CO₂, PM2.5)
# Mercado: Chile (énfasis área metropolitana, municipios, empresas privadas)
# Alineación ODS: 3 (Salud), 11 (Ciudades sostenibles), 13 (Clima)
#
# =============================================================================
# ÁREAS DE INVESTIGACIÓN REQUERIDAS:
# =============================================================================
#
# 1. ANÁLISIS DE MERCADO Y DEMANDA
#    - ¿Cuál es el tamaño y proyección del mercado de infraestructura verde urbana en Chile?
#    - ¿Cuáles son los principales drivers de demanda (regulación, ESG, conciencia climática)?
#    - ¿Cuáles municipios en Latinoamérica han implementado soluciones similares?
#    - ¿Cuáles son los estándares internacionales de edificaciones verdes?
#    - ¿Existe financiamiento disponible (CORFO, CAF, bonos verdes) para proyectos de urbanismo verde?
#
# 2. ANÁLISIS TÉCNICO Y VIABILIDAD
#    - ¿Cuáles son las especies de plantas más efectivas para purificación de aire urbano?
#    - ¿Qué tecnologías IoT se utilizan actualmente para monitoreo ambiental en sistemas verdes?
#    - ¿Cuál es el costo aproximado de instalación de muros verdes inteligentes por m²?
#    - ¿Cuál es el consumo energético y de agua para mantener un sistema de jardín vertical?
#    - ¿Existen estándares o certificaciones internacionales (LEED, BREEAM) que valoren estos sistemas?
#    - ¿Cuáles son los desafíos técnicos más comunes en sistemas de jardines verticales?
#
# 3. IMPACTO AMBIENTAL CUANTIFICABLE
#    - ¿Cuánta cantidad de CO₂ puede absorber un muro verde de 1 m² en un año?
#    - ¿Cuál es la reducción documentada de PM2.5 alrededor de áreas verdes urbanas?
#    - ¿Cuál es el efecto de enfriamiento (°C) que produce un muro verde en su entorno?
#    - ¿Hay estudios que cuantifiquen el impacto en calidad de vida y reducción de estrés?
#    - ¿Existe literatura científica sobre la efectividad de jardines verticales vs. áreas verdes horizontales?
#
# 4. MODELO DE NEGOCIO Y VIABILIDAD ECONÓMICA
#    - ¿Cuáles son los modelos de ingresos más efectivos para empresas de infraestructura verde?
#    - ¿Cuál sería el precio de mercado por m² de instalación + monitoreo por suscripción?
#    - ¿Cuál es el costo de operación y mantenimiento anual?
#    - ¿Cuáles son los indicadores clave de rentabilidad (ROI, payback period)?
#    - ¿Existen estudios de disposición a pagar de municipios y empresas por estos servicios?
#
# 5. ANÁLISIS DE COMPETENCIA
#    - ¿Cuáles son los principales competidores globales en soluciones de infraestructura verde inteligente?
#    - ¿Cuáles son los competidores en Latinoamérica y Chile específicamente?
#    - ¿Cuál es la propuesta de valor diferenciadora de cada competidor?
#    - ¿Cuáles son las barreras de entrada para nuevos competidores?
#    - ¿Existen asociaciones o patentes que protejan tecnologías similares?
#
# 6. REGULACIÓN Y POLÍTICAS PÚBLICAS
#    - ¿Cuáles son las políticas de cambio climático vigentes en Chile que favorezcan urbanismo verde?
#    - ¿Existen incentivos fiscales o subsidios para proyectos de infraestructura verde?
#    - ¿Cuáles son los estándares de calidad del aire (NAAQS) que los municipios deben cumplir?
#    - ¿Existe regulación o normativa sobre áreas verdes mínimas en ciudades chilenas?
#    - ¿Cuáles instrumentos de política pública podrían ser aliados (NDC, PNUD, etc.)?
#
# 7. OPORTUNIDADES DE ALIANZAS Y ESCALAMIENTO
#    - ¿Cuáles son los principales actores en ecosistema de innovación urbana (municipios, startups, ONG)?
#    - ¿Cuáles universidades o centros de investigación investigan urbanismo verde?
#    - ¿Cuáles constructoras e inmobiliarias líderes en Chile tienen iniciativas de sostenibilidad?
#    - ¿Cuáles fondos de inversión de impacto invierten en tecnología verde?
#    - ¿Cuáles organizaciones internacionales (ONU, CAF, BID) podrían respaldar el proyecto?
#
# 8. RIESGOS Y LIMITACIONES
#    - ¿Cuáles son los principales riesgos técnicos (plagas, enfermedades de plantas)?
#    - ¿Cuáles son los riesgos de adopción (resistencia del mercado, barreras culturales)?
#    - ¿Cuáles son los riesgos climáticos o ambientales (sequía, temperaturas extremas)?
#    - ¿Cuál es la durabilidad esperada de un sistema de muro verde inteligente?
#    - ¿Existen limitaciones geográficas o climáticas para implementación en Latinoamérica?
#
# =============================================================================
# FORMATO DE RESPUESTA SOLICITADO:
# =============================================================================
#
# Para cada área de investigación, proporciona:
#
# 1. **Hallazgos Clave**: Los 3-5 insights más importantes
# 2. **Datos Cuantitativos**: Números, porcentajes, estadísticas (con fuentes cuando sea posible)
# 3. **Oportunidades para EOLIA**: Cómo aprovechar estos hallazgos
# 4. **Recomendaciones Específicas**: Acciones concretas basadas en los hallazgos
# 5. **Referencias y Fuentes**: Donde encontrar más información
#
# =============================================================================
# PREGUNTAS SÍNTESIS FINALES:
# =============================================================================
#
# 1. ¿Cuáles son los TOP 5 municipios en Chile con mayor potencial para EOLIA?
# 2. ¿Cuál sería el pitch perfecto para convencer a un alcalde?
# 3. ¿Cuál sería el pitch perfecto para convencer a una empresa privada (ESG)?
# 4. ¿Cuáles son las métricas de impacto más valoradas por inversionistas de impacto?
# 5. ¿Cuál es la ventana de oportunidad temporal para escalar EOLIA (1-3 años, 3-5 años, 5+ años)?
#
# =============================================================================
# INSTRUCCIONES ADICIONALES:
# =============================================================================
#
# - Sé riguroso con la información: verifica datos y menciona niveles de certeza
# - Contextualiza para Chile y Latinoamérica, no solo mercados desarrollados
# - Identifica brechas de información donde sea necesario investigación primaria
# - Proporciona información accionable que pueda usarse en un informe ejecutivo
# - Mantén neutralidad pero sé constructivo en análisis de viabilidad
# ```

# %% [markdown]
# ## Sección 2: Variables de Entrada para Personalización
#
# Puedes adaptar el prompt anterior modificando estos parámetros según tus necesidades específicas:

# %%
# Variables de configuración del prompt
INVESTIGACION_CONFIG = {
    # Información del proyecto
    "nombre_proyecto": "EOLIA",
    "categoria": "Urbanismo Inteligente + Innovación Científico-Tecnológica",
    "tipo_solucion": "Jardines verticales inteligentes con IoT",
    
    # Geografía y mercado
    "paises_objetivo": ["Chile", "Latinoamérica"],
    "ciudades_prioritarias": ["Santiago"],
    "segmentos_clientes": ["Municipios", "Empresas privadas", "Instituciones educativas"],
    
    # ODS y sostenibilidad
    "ods_alineados": [3, 11, 13],
    "metricas_impacto": ["CO2 absorbido", "PM2.5 reducido", "Temperatura superficial", "Bienestar urbano"],
    
    # Etapas del proyecto
    "etapa_actual": "Validación",
    "sitios_piloto": ["Colegio", "CESFAM"],
    "modulo_base": "2 m²",
    
    # Sensores y tecnología
    "sensores": ["temperatura", "humedad", "CO2", "PM2.5"],
    "capacidad_plantas": 50,
    
    # Financiamiento
    "fuentes_potenciales": ["CORFO", "Start-Up Chile", "Bonos verdes", "Fondos de impacto"],
    
    # Timeline
    "timeline_comercializacion": "2026",
    "horizonte_escala": "3-5 años"
}

print("✅ Configuración de investigación para EOLIA cargada")
print(f"\nParámetros clave:")
for key, value in INVESTIGACION_CONFIG.items():
    print(f"  • {key}: {value}")

# %% [markdown]
# ## Sección 3: Áreas de Investigación Prioritarias
#
# Estos son los temas donde obtendrás más valor al consultar a un Language Model especialista:

# %%
# Áreas de investigación con nivel de prioridad
AREAS_INVESTIGACION = {
    "Análisis de Mercado": {
        "prioridad": "🔴 CRÍTICA",
        "temas": [
            "Tamaño y proyección del mercado de infraestructura verde en Chile",
            "Drivers principales de demanda (regulación, ESG, conciencia ambiental)",
            "Municipios con mayor déficit de áreas verdes",
            "Empresas chilenas con iniciativas ESG activas",
            "Disposición a pagar por soluciones de urbanismo verde"
        ]
    },
    "Viabilidad Técnica": {
        "prioridad": "🔴 CRÍTICA",
        "temas": [
            "Plantas más efectivas para purificación de aire en climas mediterráneos",
            "Tecnologías IoT de bajo costo para monitoreo ambiental",
            "Consumo energético y de agua de sistemas de muros verdes",
            "Problemas técnicos comunes y soluciones",
            "Durabilidad esperada (ciclo de vida del sistema)"
        ]
    },
    "Impacto Ambiental Cuantificable": {
        "prioridad": "🔴 CRÍTICA",
        "temas": [
            "Cantidad de CO₂ absorbido por m² de muro verde anualmente",
            "Reducción documentada de PM2.5 en estudios científicos",
            "Efecto de enfriamiento microclimático (island effect)",
            "Impacto en salud mental y bienestar urbano",
            "Validación científica de jardines verticales vs. horizontales"
        ]
    },
    "Modelo de Negocio": {
        "prioridad": "🟠 ALTA",
        "temas": [
            "Modelos de ingresos más efectivos (CAPEX, OPEX, subscripción, datos)",
            "Precios de mercado por m² instalado",
            "Costos operacionales y márgenes de utilidad",
            "Payback period y ROI típicos",
            "Casos de éxito en Latinoamérica"
        ]
    },
    "Análisis de Competencia": {
        "prioridad": "🟠 ALTA",
        "temas": [
            "Competidores globales en infraestructura verde inteligente",
            "Competencia directa e indirecta en Chile",
            "Diferenciadores competitivos de cada jugador",
            "Barreras de entrada (patentes, costos, expertise)",
            "Posición de EOLIA en el mercado"
        ]
    },
    "Regulación y Políticas": {
        "prioridad": "🟠 ALTA",
        "temas": [
            "Políticas de cambio climático vigentes en Chile (NDC, PNUMA)",
            "Incentivos fiscales para urbanismo verde",
            "Estándares de calidad del aire (NAAQS) por municipio",
            "Normativas sobre áreas verdes mínimas",
            "Instrumentos de política pública aliados"
        ]
    },
    "Alianzas y Escalamiento": {
        "prioridad": "🟡 MEDIA",
        "temas": [
            "Actores clave en ecosistema de innovación urbana",
            "Centros de investigación especializados",
            "Constructoras e inmobiliarias con iniciativas sostenibles",
            "Fondos de inversión de impacto en Latinoamérica",
            "Organizaciones internacionales (ONU-Habitat, CAF, BID)"
        ]
    },
    "Riesgos y Limitaciones": {
        "prioridad": "🟡 MEDIA",
        "temas": [
            "Riesgos técnicos (plagas, enfermedades, salinidad)",
            "Riesgos de adopción y barreras culturales",
            "Riesgos climáticos (sequía, temperaturas extremas)",
            "Limitaciones geográficas en Latinoamérica",
            "Cadena de suministro de componentes"
        ]
    }
}

print("📊 ÁREAS DE INVESTIGACIÓN PRIORIZADA PARA EOLIA\n")
for area, info in AREAS_INVESTIGACION.items():
    print(f"{info['prioridad']} {area}")
    for tema in info['temas']:
        print(f"    └─ {tema}")
    print()

# %% [markdown]
# ## Sección 4: Plantilla de Respuestas Esperadas
#
# Cuando consultes al Language Model, espera respuestas estructuradas así:

# %% [markdown]
# ### ESTRUCTURA ESPERADA DE RESPUESTA POR CADA ÁREA:
#
# ```markdown
# ## [NOMBRE DEL ÁREA]
#
# ### 🎯 Hallazgos Clave
# - Hallazgo 1: [Insight principal con contexto]
# - Hallazgo 2: [Insight principal con contexto]
# - Hallazgo 3: [Insight principal con contexto]
#
# ### 📊 Datos Cuantitativos
# | Métrica | Valor | Fuente | Año |
# |---------|-------|--------|------|
# | | | | |
#
# ### 💡 Oportunidades para EOLIA
# - Oportunidad 1: [Descripción específica]
# - Oportunidad 2: [Descripción específica]
#
# ### ✅ Recomendaciones Específicas
# 1. Acción 1: [Descripción detallada]
# 2. Acción 2: [Descripción detallada]
#
# ### 📚 Fuentes y Referencias
# - [Título]: [URL/Referencia]
# - [Título]: [URL/Referencia]
# ```

# %% [markdown]
# ## Sección 5: Preguntas de Síntesis para Derivar Acciones
#
# Después de recopilar toda la información, haz al LM estas preguntas síntesis:

# %%
PREGUNTAS_SINTESIS = [
    {
        "pregunta": "¿Cuáles son los TOP 5 municipios en Chile con mayor potencial para EOLIA?",
        "criterios_evaluacion": [
            "Déficit crítico de áreas verdes (< 5 m²/habitante)",
            "Índices de contaminación elevados (ICAP alto)",
            "Presencia de municipalidades progresistas en sostenibilidad",
            "Densidad de población y parque inmobiliario",
            "Presencia de instituciones educativas y públicas grandes"
        ],
        "usa_para": "Priorización geográfica inicial"
    },
    {
        "pregunta": "¿Cuál sería el pitch perfecto para convencer a un alcalde?",
        "criterios_evaluacion": [
            "Cumplimiento de objetivos climáticos municipales",
            "Retorno de imagen y legitimidad política",
            "Viabilidad presupuestaria (CAPEX y OPEX)",
            "Generación de datos para reportes obligatorios",
            "Impacto social mensurable y comunicable"
        ],
        "usa_para": "Desarrollo de pitch municipal"
    },
    {
        "pregunta": "¿Cuál sería el pitch perfecto para convencer a una empresa privada (ESG)?",
        "criterios_evaluacion": [
            "Alineación con reportes ESG y SASB",
            "Generación de storytelling de impacto",
            "Certificaciones obtenibles (LEED, BREEAM points)",
            "ROI y payback period",
            "Diferenciación competitiva en mercado"
        ],
        "usa_para": "Desarrollo de pitch corporativo"
    },
    {
        "pregunta": "¿Cuáles son las métricas de impacto más valoradas por inversionistas de impacto?",
        "criterios_evaluacion": [
            "SDG Impact Management & Accounting Tool (SDSN)",
            "Impact Weighted Accounts (IWA)",
            "Net Present Value de impacto social y ambiental",
            "Escalabilidad y replicabilidad",
            "Mitigación de co-beneficios y riesgos"
        ],
        "usa_para": "Preparación para rondas de inversión"
    },
    {
        "pregunta": "¿Cuál es la ventana de oportunidad temporal para escalar EOLIA? (1-3 años, 3-5 años, 5+ años)",
        "criterios_evaluacion": [
            "Madurez tecnológica actual",
            "Ciclos de inversión pública y privada",
            "Trajectoria de políticas climáticas",
            "Disponibilidad de financiamiento",
            "Tiempo requerido para validación de modelo"
        ],
        "usa_para": "Planificación estratégica a largo plazo"
    }
]

print("❓ PREGUNTAS DE SÍNTESIS PARA DERIVAR ACCIONES\n")
for i, item in enumerate(PREGUNTAS_SINTESIS, 1):
    print(f"{i}. {item['pregunta']}")
    print(f"   Usa para: {item['usa_para']}")
    print()

# %% [markdown]
# ## Sección 6: Flujo de Investigación Recomendado
#
# Sigue este flujo para maximizar la calidad de información obtenida:

# %%
# Flujo de investigación con Language Model
flujo_investigacion = {
    "Fase 1: Preparación": {
        "duracion": "1 sesión",
        "acciones": [
            "1.1 Copia el prompt especialista en tu herramienta de LM (ChatGPT, Claude, etc.)",
            "1.2 Proporciona el contexto completo de EOLIA (documentos del proyecto)",
            "1.3 Define el nivel de detalle esperado (executive summary vs. deep dive)",
            "1.4 Especifica el idioma preferido (español para reportes ejecutivos locales)"
        ]
    },
    "Fase 2: Investigación Principal": {
        "duracion": "3-5 sesiones",
        "acciones": [
            "2.1 Solicita análisis por cada área de investigación prioritaria",
            "2.2 Pide que estructure respuestas según template proporcionado",
            "2.3 Solicita referencias y fuentes verificables",
            "2.4 Pide matización de incertidumbres y asunciones",
            "2.5 Valida información crítica con fuentes complementarias"
        ]
    },
    "Fase 3: Síntesis y Derivación de Acciones": {
        "duracion": "1-2 sesiones",
        "acciones": [
            "3.1 Solicita respuestas a las 5 preguntas de síntesis",
            "3.2 Pide matriz de oportunidades vs. riesgos",
            "3.3 Solicita roadmap de próximas acciones por área",
            "3.4 Pide resumen ejecutivo de 2 págs con hallazgos clave"
        ]
    },
    "Fase 4: Validación y Documentación": {
        "duracion": "1 sesión",
        "acciones": [
            "4.1 Revisa información con expertos/asesores clave",
            "4.2 Verifica datos críticos con fuentes primarias",
            "4.3 Incorpora feedback y ajusta conclusiones",
            "4.4 Documenta todas las respuestas para futuro acceso"
        ]
    }
}

print("🔄 FLUJO DE INVESTIGACIÓN CON LANGUAGE MODEL\n")
for fase, contenido in flujo_investigacion.items():
    print(f"\n{fase} ({contenido['duracion']})")
    print("=" * 70)
    for accion in contenido['acciones']:
        print(f"  ✓ {accion}")

# %% [markdown]
# ## Sección 7: Documentación de Resultados
#
# Usa esta plantilla para documentar los hallazgos clave de tu investigación:

# %%
# Plantilla de documentación de resultados
resultado_investigacion = {
    "titulo": "Investigación de Mercado y Viabilidad - EOLIA",
    "fecha_investigacion": "Diciembre 2024",
    "metodologia": "Language Model Specialization + Research",
    
    "hallazgos_por_area": {
        # Reemplaza con hallazgos reales obtenidos
        "Análisis de Mercado": {
            "tamaño_mercado": "Por completar",
            "tasa_crecimiento": "Por completar",
            "principales_drivers": "Por completar"
        },
        "Viabilidad Técnica": {
            "factibilidad": "Por completar",
            "principales_desafios": "Por completar",
            "durabilidad_estimada": "Por completar"
        },
        "Impacto Ambiental": {
            "co2_absorbido_año": "Por completar",
            "pm25_reduccion": "Por completar",
            "cooling_effect": "Por completar"
        },
        "Viabilidad Económica": {
            "costo_instalacion_m2": "Por completar",
            "costo_operacional_anual": "Por completar",
            "roi_esperado": "Por completar",
            "payback_period": "Por completar"
        }
    },
    
    "oportunidades_principales": [
        {"oportunidad": "Por completar", "potencial": "Por completar"},
        {"oportunidad": "Por completar", "potencial": "Por completar"},
        {"oportunidad": "Por completar", "potencial": "Por completar"}
    ],
    
    "riesgos_principales": [
        {"riesgo": "Por completar", "mitigacion": "Por completar"},
        {"riesgo": "Por completar", "mitigacion": "Por completar"},
        {"riesgo": "Por completar", "mitigacion": "Por completar"}
    ],
    
    "municipios_objetivo_top5": [
        {"municipio": "Por completar", "ranking": 1, "justificacion": "Por completar"},
        {"municipio": "Por completar", "ranking": 2, "justificacion": "Por completar"},
        {"municipio": "Por completar", "ranking": 3, "justificacion": "Por completar"},
        {"municipio": "Por completar", "ranking": 4, "justificacion": "Por completar"},
        {"municipio": "Por completar", "ranking": 5, "justificacion": "Por completar"}
    ],
    
    "recomendaciones_acciones": [
        {"accion": "Por completar", "plazo": "Corto plazo (1-3 meses)", "propietario": "Por completar"},
        {"accion": "Por completar", "plazo": "Mediano plazo (3-6 meses)", "propietario": "Por completar"},
        {"accion": "Por completar", "plazo": "Largo plazo (6-12 meses)", "propietario": "Por completar"}
    ]
}

print("📋 PLANTILLA DE DOCUMENTACIÓN DE RESULTADOS LISTA")
print(f"\nTítulo: {resultado_investigacion['titulo']}")
print(f"Metodología: {resultado_investigacion['metodologia']}")
print(f"\nÁreas a completar: {len(resultado_investigacion['hallazgos_por_area'])}")
print(f"\nEsta plantilla debe ser completada con hallazgos reales del LM\ny guardada como parte del informe final.")

# %% [markdown]
# ## Próximos Pasos
#
# 1. **Copia el prompt especialista** (Sección 2) en tu herramienta de Language Model preferida
# 2. **Ejecuta la investigación** por fases según el flujo recomendado (Sección 6)
# 3. **Documenta todos los hallazgos** usando la plantilla (Sección 7)
# 4. **Valida información crítica** con expertos locales y fuentes primarias
# 5. **Integra resultados** en el informe LaTeX de EOLIA
#
# ### Herramientas Recomendadas para LM:
# - **ChatGPT Plus** (OpenAI) - Versatilidad y actualizaciones regulares
# - **Claude** (Anthropic) - Excelente para análisis técnicos y nuances
# - **Gemini** (Google) - Acceso a búsqueda en tiempo real
#
# ---
#
# **Última actualización**: Diciembre 2024
# **Proyecto**: EOLIA - Urbanismo Inteligente
